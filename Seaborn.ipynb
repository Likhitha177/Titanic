# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhitha177/Titanic/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df1=sns.load_dataset('titanic')
df2=sns.load_dataset('tips')
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=df2['total_bill'],y=df2['tip'],hue=df2['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=df1['age'],y=df1['fare'],hue=df1['survived'])
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(x=df1['pclass'],y=df1['age'],hue=df1['sex'])
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x=df1['sex'],y=df1['age'],hue=df1['survived'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.distplot(df1[df1['survived']==0]['age'],hist=False)
sns.distplot(df1[df1['survived']==1]['age'],hist=False)
# Out:
# <ipython-input-11-fd3b525a6253>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[df1['survived']==0]['age'],hist=False)
# <ipython-input-11-fd3b525a6253>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
import pandas as pd
sns.heatmap(pd.crosstab(df1['pclass'],df1['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
pd.crosstab(df1['pclass'],df1['survived'])
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.pairplot(df2,hue='sex')

# %%
df2[['total_bill','tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.heatmap(df2[['total_bill','tip']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['age','fare','parch','sibsp']].corr())
# Out:
# <Axes: >
